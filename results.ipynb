# %%
import os
import sys
import numpy as np
import pandas as pd
from scripts.helpers import *
from scripts.denoising_pipeline import *

# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
# Get paths
data_path, output_path = get_paths()

# Define global parameter ranges
PARAMETER_RANGES = {
    "Gaussian": {"param_name": "sigma", "values": [2, 5, 8]},
    "Median": {"param_name": "size", "values": [5, 8, 10]},
    "TV-Chambolle": {"param_name": "weight", "values": [0.1, 0.2, 0.3]},
    "Wavelet": {"param_name": None, "values": None},  # Use default parameters
    "NL-Means": {"param_name": None, "values": None},  # Use default parameters
    "TV-ISO": {"param_name": "lmbda", "values": [0.05, 0.08, 0.1]},
    "BM3D": {"param_name": "sigma_psd", "values": [0.05, 0.1, 0.15]}, 
    "Noise2Noise": {"param_name": None, "values": None},  # Use default parameters
    "Noise2Void": {"param_name": None, "values": None}  # Use default parameters
}

disable_progress = True  # Set to False to enable progress bar

# Choose denoiser
denoiser_name = "Gaussian"  # "Gaussian", "Median", "TV-Chambolle", "Wavelet", "NL-Means", "TV-ISO", "BM3D", "Noise2Noise", "Noise2Void"

# %%
output_path, data_path
# Out:
# ('/Users/gattimartina/Documents/EPFL/Master/MA1/ML/projects/ML4Science-CS433/data/output/',
#  '/Users/gattimartina/Documents/EPFL/Master/MA1/ML/projects/ML4Science-CS433/data/raw/')

# %%
# Run the denoising pipeline
denoising_pipeline(data_path, output_path, denoiser_name, PARAMETER_RANGES, num_images=120, num_channels=3, disable_progress=disable_progress)
# Out:
# INFO:root:Starting denoising pipeline...
# INFO:root:Processing channel 0...
# Images in channel 0:   0%|          | 0/120 [00:00<?, ?it/s]INFO:root:Processing image 001...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Denoised image saved to /Users/gattimartina/Documents/EPFL/Master/MA1/ML/projects/ML4Science-CS433/data/processed/Gaussian/Gaussian_denoised_channel0_image001_param2.npy
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Denoised image saved to /Users/gattimartina/Documents/EPFL/Master/MA1/ML/projects/ML4Science-CS433/data/processed/Gaussian/Gaussian_denoised_channel0_image001_param5.npy
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Denoised image saved to /Users/gattimartina/Documents/EPFL/Master/MA1/ML/projects/ML4Science-CS433/data/processed/Gaussian/Gaussian_denoised_channel0_image001_param8.npy
# Images in channel 0:   1%|          | 1/120 [00:00<00:34,  3.48it/s]INFO:root:Processing image 002...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 0:   2%|▏         | 2/120 [00:00<00:31,  3.79it/s]INFO:root:Processing image 003...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 0:   2%|▎         | 3/120 [00:00<00:29,  3.99it/s]INFO:root:Processing image 004...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 0:   3%|▎         | 4/120 [00:01<00:28,  4.10it/s]INFO:root:Processing image 005...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 0:   4%|▍         | 5/120 [00:01<00:30,  3.72it/s]INFO:root:Processing image 006...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 0:   5%|▌         | 6/120 [00:01<00:33,  3.43it/s]INFO:root:Processing image 007...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 0:   6%|▌         | 7/120 [00:01<00:32,  3.44it/s]INFO:root:Processing image 008...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 0:   7%|▋         | 8/120 [00:02<00:31,  3.59it/s]INFO:root:Processing image 009...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 0

# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  72%|███████▏  | 86/120 [00:22<00:08,  4.13it/s]INFO:root:Processing image 087...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  72%|███████▎  | 87/120 [00:22<00:07,  4.19it/s]INFO:root:Processing image 088...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  73%|███████▎  | 88/120 [00:23<00:07,  4.13it/s]INFO:root:Processing image 089...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  74%|███████▍  | 89/120 [00:23<00:07,  4.19it/s]INFO:root:Processing image 090...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  75%|███████▌  | 90/120 [00:23<00:07,  3.97it/s]INFO:root:Processing image 091...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  76%|███████▌  | 91/120 [00:23<00:07,  4.01it/s]INFO:root:Processing image 092...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  77%|███████▋  | 92/120 [00:24<00:06,  4.01it/s]INFO:root:Processing image 093...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  78%|███████▊  | 93/120 [00:24<00:06,  4.12it/s]INFO:root:Processing image 094...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  78%|███████▊  | 94/120 [00:24<00:06,  4.08it/s]INFO:root:Processing image 095...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  79%|███████▉  | 95/120 [00:24<00:06,  4.06it/s]INFO:root:Processing image 096...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  80%|████████  | 96/120 [00:25<00:06,  3.87it/s]INFO:root:Processing image 097...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  81%|████████  | 97/120 [00:25<00:05,  4.01it/s]INFO:root:Processing image 098...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  82%|████████▏ | 98/120 [00:25<00:05,  3.94it/s]INFO:root:Processing image 099...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  82%|████████▎ | 99/120 [00:25<00:05,  3.94it/s]INFO:root:Processing image 100...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  83%|████████▎ | 100/120 [00:26<00:05,  3.69it/s]INFO:root:Processing image 101...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  84%|████████▍ | 101/120 [00:26<00:04,  3.82it/s]INFO:root:Processing image 102...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  85%|████████▌ | 102/120 [00:26<00:04,  3.83it/s]INFO:root:Processing image 103...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  86%|████████▌ | 103/120 [00:27<00:04,  3.93it/s]INFO:root:Processing image 104...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  87%|████████▋ | 104/120 [00:27<00:04,  3.92it/s]INFO:root:Processing image 105...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  88%|████████▊ | 105/120 [00:27<00:03,  4.04it/s]INFO:root:Processing image 106...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  88%|████████▊ | 106/120 [00:27<00:03,  4.01it/s]INFO:root:Processing image 107...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  89%|████████▉ | 107/120 [00:28<00:03,  3.79it/s]INFO:root:Processing image 108...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  90%|█████████ | 108/120 [00:28<00:03,  3.87it/s]INFO:root:Processing image 109...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  91%|█████████ | 109/120 [00:28<00:02,  3.94it/s]INFO:root:Processing image 110...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  92%|█████████▏| 110/120 [00:28<00:02,  3.90it/s]INFO:root:Processing image 111...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  92%|█████████▎| 111/120 [00:29<00:02,  3.75it/s]INFO:root:Processing image 112...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  93%|█████████▎| 112/120 [00:29<00:02,  3.54it/s]INFO:root:Processing image 113...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  94%|█████████▍| 113/120 [00:29<00:02,  3.46it/s]INFO:root:Processing image 114...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  95%|█████████▌| 114/120 [00:30<00:01,  3.06it/s]INFO:root:Processing image 115...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  96%|█████████▌| 115/120 [00:30<00:01,  3.26it/s]INFO:root:Processing image 116...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  97%|█████████▋| 116/120 [00:30<00:01,  3.49it/s]INFO:root:Processing image 117...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  98%|█████████▊| 117/120 [00:30<00:00,  3.64it/s]INFO:root:Processing image 118...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  98%|█████████▊| 118/120 [00:31<00:00,  3.75it/s]INFO:root:Processing image 119...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2:  99%|█████████▉| 119/120 [00:31<00:00,  3.71it/s]INFO:root:Processing image 120...
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 2}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 5}...
# INFO:root:Computing metrics for denoised image.
# INFO:root:Applying denoiser Gaussian with parameters {'sigma': 8}...
# INFO:root:Computing metrics for denoised image.
# Images in channel 2: 100%|██████████| 120/120 [00:31<00:00,  3.79it/s]
# INFO:root:Saving results for channel 2...
# INFO:root:Saving average results...

# %%
results_df = pd.read_csv(os.path.join(output_path, f"{denoiser_name}/avg_{denoiser_name}_denoiser_results.csv"))

# Display and save the results
display_styled_results(results_df, output_path, f"{denoiser_name}_styled_results.csv", f"{denoiser_name} Denoising Results")
# Out:
# INFO:root:
# Gaussian Denoising Results:
# <style type="text/css">
# #T_80dba_row0_col3, #T_80dba_row0_col4, #T_80dba_row0_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_80dba_row1_col3, #T_80dba_row8_col5 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_80dba_row1_col4, #T_80dba_row5_col5 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_80dba_row1_col5 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_80dba_row2_col3 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_80dba_row2_col4 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_80dba_row2_col5 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_80dba_row3_col3 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_80dba_row3_col4 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_80dba_row3_col5 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_80dba_row4_col3 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_80dba_row4_col4 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_80dba_row4_col5 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_80dba_row5_col3 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_80dba_row5_col4 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_80dba_row6_col3 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_80dba_row6_col4, #T_80dba_row7_col3, #T_80dba_row7_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_80dba_row6_col5 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_80dba_row7_col4 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_80dba_row8_col3 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_80dba_row8_col4 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# </style>
# <table id="T_80dba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80dba_level0_col0" class="col_heading level0 col0" >DenoiserType</th>
#       <th id="T_80dba_level0_col1" class="col_heading level0 col1" >Parameter</th>
#       <th id="T_80dba_level0_col2" class="col_heading level0 col2" >Channel</th>
#       <th id="T_80dba_level0_col3" class="col_heading level0 col3" >PSNR</th>
#       <th id="T_80dba_level0_col4" class="col_heading level0 col4" >SI-PSNR</th>
#       <th id="T_80dba_level0_col5" class="col_heading level0 col5" >SSIM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80dba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80dba_row0_col0" class="data row0 col0" >Gaussian</td>
#       <td id="T_80dba_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_80dba_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_80dba_row0_col3" class="data row0 col3" >31.86</td>
#       <td id="T_80dba_row0_col4" class="data row0 col4" >35.19</td>
#       <td id="T_80dba_row0_col5" class="data row0 col5" >0.9028</td>
#     </tr>
#     <tr>
#       <th id="T_80dba_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_80dba_row1_col0" class="data row1 col0" >Gaussian</td>
#       <td id="T_80dba_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_80dba_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_80dba_row1_col3" class="data row1 col3" >24.14</td>
#       <td id="T_80dba_row1_col4" class="data row1 col4" >33.10</td>
#       <td id="T_80dba_row1_col5" class="data row1 col5" >0.7828</td>
#     </tr>
#     <tr>
#       <th id="T_80dba_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_80dba_row2_col0" class="data row2 col0" >Gaussian</td>
#       <td id="T_80dba_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_80dba_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_80dba_row2_col3" class="data row2 col3" >30.55</td>
#       <td id="T_80dba_row2_col4" class="data row2 col4" >34.89</td>
#       <td id="T_80dba_row2_col5" class="data row2 col5" >0.8143</td>
#     </tr>
#     <tr>
#       <th id="T_80dba_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_80dba_row3_col0" class="data row3 col0" >Gaussian</td>
#       <td id="T_80dba_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_80dba_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_80dba_row3_col3" class="data row3 col3" >24.50</td>
#       <td id="T_80dba_row3_col4" class="data row3 col4" >29.88</td>
#       <td id="T_80dba_row3_col5" class="data row3 col5" >0.8446</td>
#     </tr>
#     <tr>
#       <th id="T_80dba_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_80dba_row4_col0" class="data row4 col0" >Gaussian</td>
#       <td id="T_80dba_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_80dba_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_80dba_row4_col3" class="data row4 col3" >18.55</td>
#       <td id="T_80dba_row4_col4" class="data row4 col4" >30.70</td>
#       <td id="T_80dba_row4_col5" class="data row4 col5" >0.7249</td>
#     </tr>
#     <tr>
#       <th id="T_80dba_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_80dba_row5_col0" class="data row5 col0" >Gaussian</td>
#       <td id="T_80dba_row5_col1" class="data row5 col1" >5</td>
#       <td id="T_80dba_row5_col2" class="data row5 col2" >2</td>
#       <td id="T_80dba_row5_col3" class="data row5 col3" >24.20</td>
#       <td id="T_80dba_row5_col4" class="data row5 col4" >32.63</td>
#       <td id="T_80dba_row5_col5" class="data row5 col5" >0.8421</td>
#     </tr>
#     <tr>
#       <th id="T_80dba_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_80dba_row6_col0" class="data row6 col0" >Gaussian</td>
#       <td id="T_80dba_row6_col1" class="data row6 col1" >8</td>
#       <td id="T_80dba_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_80dba_row6_col3" class="data row6 col3" >21.44</td>
#       <td id="T_80dba_row6_col4" class="data row6 col4" >27.38</td>
#       <td id="T_80dba_row6_col5" class="data row6 col5" >0.7748</td>
#     </tr>
#     <tr>
#       <th id="T_80dba_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_80dba_row7_col0" class="data row7 col0" >Gaussian</td>
#       <td id="T_80dba_row7_col1" class="data row7 col1" >8</td>
#       <td id="T_80dba_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_80dba_row7_col3" class="data row7 col3" >16.77</td>
#       <td id="T_80dba_row7_col4" class="data row7 col4" >29.18</td>
#       <td id="T_80dba_row7_col5" class="data row7 col5" >0.6774</td>
#     </tr>
#     <tr>
#       <th id="T_80dba_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_80dba_row8_col0" class="data row8 col0" >Gaussian</td>
#       <td id="T_80dba_row8_col1" class="data row8 col1" >8</td>
#       <td id="T_80dba_row8_col2" class="data row8 col2" >2</td>
#       <td id="T_80dba_row8_col3" class="data row8 col3" >20.49</td>
#       <td id="T_80dba_row8_col4" class="data row8 col4" >30.02</td>
#       <td id="T_80dba_row8_col5" class="data row8 col5" >0.7867</td>
#     </tr>
#   </tbody>
# </table>
